# %% [markdown]
# # Pythonic Pandas - A Refresher
#
# This is a quick notebook to help tie back some of what was covered in `cheatsheet.py` to the way we use Pandas to analyze data. Use this document as a reminder that the tools and abstractions provided by Pandas are based on the features that make Python Python.
#
# > Note: This isn't necessarily the best, most pandas-y notebook ever. See the other notesbooks in this file for that.

# %%
import pandas as pd

# %% [markdown]
# `import` statements pull in modules, which are full of functions and classes that give us easy access to complex features. `as` lets use use a shorter, friendly name for our modules if we'd like.

# %%
df = pd.read_csv('oscar_winners.csv')

# %% [markdown]
# *Assignment* happens when we use a `=` to give a variable a value. Right now, we just used a *function* included in the pandas *module* to set the value of the brand new *variable*, `df` (dataframe) to whatever `returns` out of the `read_csv` function.
#
# > Remember: We don't see any output unless there's a problem. Function calls and other plain old *references* are the way to look at stuff in Jupyter.

# %%
type(df) # call the type funtion
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In this case, what got returned was an *instance* of the `DataFrame` class that the authors of pandas kindly created for us. (OnlyClassesGetTitleCased)
#
# Let's take a look at it.

# %%
df # plain old reference
# Out:
#       1934   7                             Actor    1  \
# 0     1934   7                             Actor  NaN
# 1     1934   7                             Actor  NaN
# 2     1934   7                           Actress  1.0
# 3     1934   7                           Actress  NaN
# 4     1934   7                           Actress  NaN
# 5     1934   7                           Actress  NaN
# 6     1934   7                     Art Direction  NaN
# 7     1934   7                     Art Direction  NaN
# 8     1934   7                     Art Direction  1.0
# 9     1934   7                Assistant Director  NaN
# 10    1934   7                Assistant Director  NaN
# 11    1934   7                Assistant Director  1.0
# 12    1934   7                    Cinematography  NaN
# 13    1934   7                    Cinematography  1.0
# 14    1934   7                    Cinematography  NaN
# 15    1934   7                         Directing  1.0
# 16    1934   7                         Directing  NaN
# 17    1934   7                         Directing  NaN
# 18    1934   7                      Film Editing  NaN
# 19    1934   7                      Film Editing  1.0
# 20    1934   7                      Film Editing  NaN
# 21    1934   7                   Music (Scoring)  NaN
# 22    1934   7                   Music (Scoring)  NaN
# 23    1934   7                   Music (Scoring)  1.0
# 24    1934   7                      Music (Song)  NaN
# 25    1934   7                      Music (Song)  1.0
# 26    1934   7                      Music (Song)  NaN
# 27    1934   7            Outstanding Production  NaN
# 28    1934   7            Outstanding Production  NaN
# 29    1934   7            Outstanding Production  NaN
# ...    ...  ..                               ...  ...
# 9664  2015  88          Short Film (Live Action)  NaN
# 9665  2015  88          Short Film (Live Action)  1.0
# 9666  2015  88                     Sound Editing  1.0
# 9667  2015  88                     Sound Editing  NaN
# 9668  2015  88                     Sound Editing  NaN
# 9669  2015  88                     Sound Editing  NaN
# 9670  2015  88                     Sound Editing  NaN
# 9671  2015  88                      Sound Mixing  NaN
# 9672  2015  88                      Sound Mixing  1.0
# 9673  2015  88                      Sound Mixing  NaN
# 9674  2015  88                      Sound Mixing  NaN
# 9675  2015  88                      Sound Mixing  NaN
# 9676  2015  88                    Visual Effects  1.0
# 9677  2015  88                    Visual Effects  NaN
# 9678  2015  88                    Visual Effects  NaN
# 9679  2015  88                    Visual Effects  NaN
# 9680  2015  88                    Visual Effects  NaN
# 9681  2015  88      Writing (Adapted Screenplay)  1.0
# 9682  2015  88      Writing (Adapted Screenplay)  NaN
# 9683  2015  88      Writing (Adapted Screenplay)  NaN
# 9684  2015  88      Writing (Adapted Screenplay)  NaN
# 28                                            Paramount
# 29                                       First National
# ...                                                 ...
# 9664                                    Jamie Donoughue
# 9665                Benjamin Cleary and Serena Armitage
# 9666                       Mark Mangini and David White
# 9667                                      Oliver Tarney
# 9668                    Martin Hernandez and Lon Bender
# 9669                                 Alan Robert Murray
# 9670                       Matthew Wood and David Acord
# 9671          Andy Nelson  Gary Rydstrom and Drew Kunin
# 9672          Chris Jenkins  Gregg Rudloff and Ben Osmo
# 9673              Paul Massey  Mark Taylor and Mac Ruth
# 9674  Jon Taylor  Frank A. MontaÃƒÂ±o  Randy Thom an...
# 9675  Andy Nelson  Christopher Scarabosio and Stuart...
# 9676  Andrew Whitehurst  Paul Norris  Mark Ardington...
# 9677  Andrew Jackson  Tom Wood  Dan Oliver and Andy ...
# 9678  Richard Stammers  Anders Langlands  Chris Lawr...
# 9679  Rich McBride  Matthew Shumway  Jason Smith and...
# 9680  Roger Guyett  Patrick Tubach  Neal Scanlan and...
# 9681      Screenplay by Charles Randolph and Adam McKay
# 9682                          Screenplay by Nick Hornby
# 9683                         Screenplay by Phyllis Nagy
# 9684                         Screenplay by Drew Goddard
# 9685                        Screenplay by Emma Donoghue
# 9686  Written by Matt Charman and Ethan Coen & Joel ...
# 9687                            Written by Alex Garland
# 9688  Screenplay by Pete Docter  Meg LeFauve  Josh C...
# 9689              Written by Josh Singer & Tom McCarthy
# 9690  Screenplay by Jonathan Herman and Andrea Berlo...
# 9691                                                NaN
# 9692                                                NaN
# 9693                                                  _
#
# [9694 rows x 6 columns]

# %% [markdown]
# Wow! Look at that wonderful data-- **NOT!** Our first row of data got caught in the first row. :(
#
# Since `df` is an *instance* of a class, then it probably has some useful functions and variables (or more accurately, methods and fields) for us to use...

# %%
df.columns # an instance of the `Index` class
# Out:
# Index(['1934', '7', 'Actor', '1', 'Clark Gable', 'It Happened One Night'], dtype='object')

# %% [markdown]
# This reminds me of something... A list! It's *list-like*! `[]` Rows and headers in Pandas resemble lists in native Python. Let's replace that list with with a new one!

# %%
df.columns = ['Year', 'Ceremony', 'Award', 'Win', 'Recipient', 'Film'  ]
df.columns
# Out:
# Index(['Year', 'Ceremony', 'Award', 'Win', 'Recipient', 'Film'], dtype='object')

# %% [markdown]
# Excellent. That makes a lot more sense. Let's take a look at a column. We're gonna go ahead and *access* a column with it's name, kind of like accessing a dict `{}` with a key. You guessed it: `DataFrame`s in Pandas are *dict-like*.

# %%
type(df['Recipient'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# And the values at the 'keys' in the dict-like dataframe are list-like objects called `Series`.

# %%
df['Recipient'][1:5]  # a key/column is a string
# Out:
# 1       William Powell
# 2    Claudette Colbert
# 3          Bette Davis
# 4          Grace Moore
# Name: Recipient, dtype: object

# %% [markdown]
# We'll stop here, since now we remember that:
#
# - Pandas is a module that we can import and reference.
# ```python
# import pandas as pd
# ```
#
# - Since it's a module, it's filled with convenient functions and other tools.
# ```python
# df = pd.read_csv('a_wonderful_csv.csv')
# ```
#
# - As we use Pandas, we run into more convenient abstractions, such as the `DataFrame` class.
# ```python
# df.columns # shows us a list-like representation of the header row
# df['ColumnName'] # we can use strings to access columns, like accessing lists with dict keys
# ```
#
# Each of these have more utilities attached to them, and we'll explore them in-context next.

# %% [markdown]
# Onward to the next notebook for more in-depth work with Pandas!
